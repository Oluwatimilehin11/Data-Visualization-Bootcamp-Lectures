# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
bake = pd.read_csv('Buildings.csv')
# Out:
# C:\Users\phera\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (7,35,37,38,40,41) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
bake.head()
# Out:
#    property_id  area_id  zone_id    area_name_ar        area_name_en  \
# 0   1200000001      352        2  الثنيه الرابعة  Al Thanayah Fourth
# 1   1200000003      352        2  الثنيه الرابعة  Al Thanayah Fourth
# 2   1200000005      400        1          العياص             Al Eyas
# 3   1200000006      350        2  الثنيه الخامسة    Al Thanyah Fifth
# 4   1200000008      350        2  الثنيه الخامسة    Al Thanyah Fifth
#
#    land_number  land_sub_number building_number  common_area  \
# 0          220              0.0               3          NaN
# 1          339              0.0              91          NaN
# 2           -1              0.0               1          NaN
# 3           76              0.0        JI05M002          NaN
# 4           81              0.0        JI05M007          NaN
#
#    actual_common_area  ...  pre_registration_number  master_project_id  \
# 0                 NaN  ...                      NaN               50.0
# ...

# %%
bake.columns
# Out:
# Index(['property_id', 'area_id', 'zone_id', 'area_name_ar', 'area_name_en',
#        'land_number', 'land_sub_number', 'building_number', 'common_area',
#        'actual_common_area', 'floors', 'rooms', 'rooms_ar', 'rooms_en',
#        'car_parks', 'built_up_area', 'bld_levels', 'shops', 'flats', 'offices',
#        'swimming_pools', 'elevators', 'actual_area', 'property_type_id',
#        'property_type_ar', 'property_type_en', 'property_sub_type_id',
#        'property_sub_type_ar', 'property_sub_type_en', 'parent_property_id',
#        'creation_date', 'parcel_id', 'is_free_hold', 'is_lease_hold',
#        'is_registered', 'pre_registration_number', 'master_project_id',
#        'master_project_en', 'master_project_ar', 'project_id',
#        'project_name_ar', 'project_name_en', 'land_type_id', 'land_type_ar',
#        'land_type_en'],
#       dtype='object')

# %%
bake.shape
# Out:
# (148000, 45)

# %%
bake.isnull().sum()
# Out:
# property_id                     0
# area_id                         0
# zone_id                         0
# area_name_ar                    0
# area_name_en                    0
# land_number                     0
# land_sub_number              4648
# building_number             30732
# common_area                 78665
# actual_common_area         116426
# floors                      35258
# rooms                       36272
# rooms_ar                    36323
# rooms_en                    37363
# car_parks                   24828
# built_up_area               25021
# bld_levels                 143637
# shops                      140682
# flats                      140946
# offices                    140677
# swimming_pools             146745
# elevators                  146698
# actual_area                 13354
# property_type_id                0
# property_type_ar                0
# property_type_en                0
# property_sub_type_id            0
# ...

# %%
bake.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148000 entries, 0 to 147999
# Data columns (total 45 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   property_id              148000 non-null  int64
#  1   area_id                  148000 non-null  int64
#  2   zone_id                  148000 non-null  int64
#  3   area_name_ar             148000 non-null  object
#  4   area_name_en             148000 non-null  object
#  5   land_number              148000 non-null  int64
#  6   land_sub_number          143352 non-null  float64
#  7   building_number          117268 non-null  object
#  8   common_area              69335 non-null   float64
#  9   actual_common_area       31574 non-null   float64
#  10  floors                   112742 non-null  float64
#  11  rooms                    111728 non-null  float64
#  12  rooms_ar                 111677 non-null  object
# ...

# %%
bake.drop(columns="flats", inplace = True)
bake.head()
# Out:
#    property_id  area_id  zone_id    area_name_ar        area_name_en  \
# 0   1200000001      352        2  الثنيه الرابعة  Al Thanayah Fourth
# 1   1200000003      352        2  الثنيه الرابعة  Al Thanayah Fourth
# 2   1200000005      400        1          العياص             Al Eyas
# 3   1200000006      350        2  الثنيه الخامسة    Al Thanyah Fifth
# 4   1200000008      350        2  الثنيه الخامسة    Al Thanyah Fifth
#
#    land_number  land_sub_number building_number  common_area  \
# 0          220              0.0               3          NaN
# 1          339              0.0              91          NaN
# 2           -1              0.0               1          NaN
# 3           76              0.0        JI05M002          NaN
# 4           81              0.0        JI05M007          NaN
#
#    actual_common_area  ...  pre_registration_number  master_project_id  \
# 0                 NaN  ...                      NaN               50.0
# ...

# %%
bake.drop(columns="shops", inplace = True)
bake.head()
# Out:
#    property_id  area_id  zone_id    area_name_ar        area_name_en  \
# 0   1200000001      352        2  الثنيه الرابعة  Al Thanayah Fourth
# 1   1200000003      352        2  الثنيه الرابعة  Al Thanayah Fourth
# 2   1200000005      400        1          العياص             Al Eyas
# 3   1200000006      350        2  الثنيه الخامسة    Al Thanyah Fifth
# 4   1200000008      350        2  الثنيه الخامسة    Al Thanyah Fifth
#
#    land_number  land_sub_number building_number  common_area  \
# 0          220              0.0               3          NaN
# 1          339              0.0              91          NaN
# 2           -1              0.0               1          NaN
# 3           76              0.0        JI05M002          NaN
# 4           81              0.0        JI05M007          NaN
#
#    actual_common_area  ...  pre_registration_number  master_project_id  \
# 0                 NaN  ...                      NaN               50.0
# ...

# %%
bake.drop(columns="elevators", inplace = True)
bake.head()
# Out:
#    property_id  area_id  zone_id    area_name_ar        area_name_en  \
# 0   1200000001      352        2  الثنيه الرابعة  Al Thanayah Fourth
# 1   1200000003      352        2  الثنيه الرابعة  Al Thanayah Fourth
# 2   1200000005      400        1          العياص             Al Eyas
# 3   1200000006      350        2  الثنيه الخامسة    Al Thanyah Fifth
# 4   1200000008      350        2  الثنيه الخامسة    Al Thanyah Fifth
#
#    land_number  land_sub_number building_number  common_area  \
# 0          220              0.0               3          NaN
# 1          339              0.0              91          NaN
# 2           -1              0.0               1          NaN
# 3           76              0.0        JI05M002          NaN
# 4           81              0.0        JI05M007          NaN
#
#    actual_common_area  ...  pre_registration_number  master_project_id  \
# 0                 NaN  ...                      NaN               50.0
# ...

# %%
bake.drop(columns="area_name_ar", inplace = True)
bake.head()
# Out:
#    property_id  area_id  zone_id        area_name_en  land_number  \
# 0   1200000001      352        2  Al Thanayah Fourth          220
# 1   1200000003      352        2  Al Thanayah Fourth          339
# 2   1200000005      400        1             Al Eyas           -1
# 3   1200000006      350        2    Al Thanyah Fifth           76
# 4   1200000008      350        2    Al Thanyah Fifth           81
#
#    land_sub_number building_number  common_area  actual_common_area  floors  \
# 0              0.0               3          NaN                 NaN     NaN
# 1              0.0              91          NaN                 NaN     NaN
# 2              0.0               1          NaN                 NaN     NaN
# 3              0.0        JI05M002          NaN                 NaN     2.0
# 4              0.0        JI05M007          NaN                 NaN     2.0
#
#    ...  pre_registration_number master_project_id master_project_en  \
# ...

# %%
bake.drop(columns="swimming_pools", inplace = True)
bake.head()
# Out:
#    property_id  area_id  zone_id        area_name_en  land_number  \
# 0   1200000001      352        2  Al Thanayah Fourth          220
# 1   1200000003      352        2  Al Thanayah Fourth          339
# 2   1200000005      400        1             Al Eyas           -1
# 3   1200000006      350        2    Al Thanyah Fifth           76
# 4   1200000008      350        2    Al Thanyah Fifth           81
#
#    land_sub_number building_number  common_area  actual_common_area  floors  \
# 0              0.0               3          NaN                 NaN     NaN
# 1              0.0              91          NaN                 NaN     NaN
# 2              0.0               1          NaN                 NaN     NaN
# 3              0.0        JI05M002          NaN                 NaN     2.0
# 4              0.0        JI05M007          NaN                 NaN     2.0
#
#    ...  pre_registration_number master_project_id master_project_en  \
# ...

# %%
bake.drop(columns="actual_common_area", inplace = True)
bake.head()
# Out:
#    property_id  area_id  zone_id        area_name_en  land_number  \
# 0   1200000001      352        2  Al Thanayah Fourth          220
# 1   1200000003      352        2  Al Thanayah Fourth          339
# 2   1200000005      400        1             Al Eyas           -1
# 3   1200000006      350        2    Al Thanyah Fifth           76
# 4   1200000008      350        2    Al Thanyah Fifth           81
#
#    land_sub_number building_number  common_area  floors  rooms  ...  \
# 0              0.0               3          NaN     NaN    NaN  ...
# 1              0.0              91          NaN     NaN    NaN  ...
# 2              0.0               1          NaN     NaN    1.0  ...
# 3              0.0        JI05M002          NaN     2.0    4.0  ...
# 4              0.0        JI05M007          NaN     2.0    4.0  ...
#
#   pre_registration_number master_project_id  master_project_en  \
# 0                     NaN              50.0     Emirates Hills
# ...

# %%
bake.drop(columns="bld_levels", inplace = True)
bake.head()
# Out:
#    property_id  area_id  zone_id        area_name_en  land_number  \
# 0   1200000001      352        2  Al Thanayah Fourth          220
# 1   1200000003      352        2  Al Thanayah Fourth          339
# 2   1200000005      400        1             Al Eyas           -1
# 3   1200000006      350        2    Al Thanyah Fifth           76
# 4   1200000008      350        2    Al Thanyah Fifth           81
#
#    land_sub_number building_number  common_area  floors  rooms  ...  \
# 0              0.0               3          NaN     NaN    NaN  ...
# 1              0.0              91          NaN     NaN    NaN  ...
# 2              0.0               1          NaN     NaN    1.0  ...
# 3              0.0        JI05M002          NaN     2.0    4.0  ...
# 4              0.0        JI05M007          NaN     2.0    4.0  ...
#
#   pre_registration_number master_project_id  master_project_en  \
# 0                     NaN              50.0     Emirates Hills
# ...

# %%
bake.drop(columns="pre_registration_number", inplace = True)
bake.head()
# Out:
#    property_id  area_id  zone_id        area_name_en  land_number  \
# 0   1200000001      352        2  Al Thanayah Fourth          220
# 1   1200000003      352        2  Al Thanayah Fourth          339
# 2   1200000005      400        1             Al Eyas           -1
# 3   1200000006      350        2    Al Thanyah Fifth           76
# 4   1200000008      350        2    Al Thanyah Fifth           81
#
#    land_sub_number building_number  common_area  floors  rooms  ...  \
# 0              0.0               3          NaN     NaN    NaN  ...
# 1              0.0              91          NaN     NaN    NaN  ...
# 2              0.0               1          NaN     NaN    1.0  ...
# 3              0.0        JI05M002          NaN     2.0    4.0  ...
# 4              0.0        JI05M007          NaN     2.0    4.0  ...
#
#   is_registered master_project_id  master_project_en  master_project_ar  \
# 0           1.0              50.0     Emirates Hills      تلال الامارات
# ...

# %%
bake.drop(columns="master_project_ar" , inplace = True)
bake.head()
# Out:
#    property_id  area_id  zone_id        area_name_en  land_number  \
# 0   1200000001      352        2  Al Thanayah Fourth          220
# 1   1200000003      352        2  Al Thanayah Fourth          339
# 2   1200000005      400        1             Al Eyas           -1
# 3   1200000006      350        2    Al Thanyah Fifth           76
# 4   1200000008      350        2    Al Thanyah Fifth           81
#
#    land_sub_number building_number  common_area  floors  rooms  ...  \
# 0              0.0               3          NaN     NaN    NaN  ...
# 1              0.0              91          NaN     NaN    NaN  ...
# 2              0.0               1          NaN     NaN    1.0  ...
# 3              0.0        JI05M002          NaN     2.0    4.0  ...
# 4              0.0        JI05M007          NaN     2.0    4.0  ...
#
#   is_lease_hold is_registered  master_project_id  master_project_en  \
# 0           0.0           1.0               50.0     Emirates Hills
# ...

# %%
bake.drop(columns="land_type_ar" , inplace = True)
bake.head()
# Out:
#    property_id  area_id  zone_id        area_name_en  land_number  \
# 0   1200000001      352        2  Al Thanayah Fourth          220
# 1   1200000003      352        2  Al Thanayah Fourth          339
# 2   1200000005      400        1             Al Eyas           -1
# 3   1200000006      350        2    Al Thanyah Fifth           76
# 4   1200000008      350        2    Al Thanyah Fifth           81
#
#    land_sub_number building_number  common_area  floors  rooms  ...  \
# 0              0.0               3          NaN     NaN    NaN  ...
# 1              0.0              91          NaN     NaN    NaN  ...
# 2              0.0               1          NaN     NaN    1.0  ...
# 3              0.0        JI05M002          NaN     2.0    4.0  ...
# 4              0.0        JI05M007          NaN     2.0    4.0  ...
#
#   is_free_hold is_lease_hold  is_registered  master_project_id  \
# 0            1           0.0            1.0               50.0
# ...

# %%
building.type
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-522dce1f4644> in <module>
# ----> 1 building.type
#
# NameError: name 'building' is not defined

# %%
duplicate_rows_df = bake[bake.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)

# %%
bake.count()

# %%
print(bake.isnull().sum())

# %%
bake = bake.dropna()    # Dropping the missing values.
bake.count()

# %%
print(bake.isnull().sum())

# %%
bake.head()
