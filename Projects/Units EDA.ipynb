# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
units = pd.read_csv('Units.csv')
# Out:
# C:\Users\phera\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3,4,7,8,10,12,13,16,18,19,22,23,25,26,29,36,38,39,41,42,44,45) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
units.head()
# Out:
#    property_id  area_id  zone_id    area_name_ar      area_name_en  \
# 0   1300000003    351.0      2.0  الثنيه الثالثة  Al Thanyah Third
# 1   1300000004    351.0      2.0  الثنيه الثالثة  Al Thanyah Third
# 2   1300000005    351.0      2.0  الثنيه الثالثة  Al Thanyah Third
# 3   1300000006    351.0      2.0  الثنيه الثالثة  Al Thanyah Third
# 4   1300000007    351.0      2.0  الثنيه الثالثة  Al Thanyah Third
#
#    land_number  land_sub_number building_number unit_number  \
# 0         31.0              0.0               2         207
# 1         34.0              0.0               1         G01
# 2         34.0              0.0               1         G02
# 3         34.0              0.0               1         G03
# 4         34.0              0.0               1         G04
#
#    unit_balcony_area  ... pre_registration_number  master_project_id  \
# 0              19.97  ...                     NaN               33.0
# ...

# %%
units.drop(columns="area_name_ar", inplace = True)
units.head()
# Out:
#    property_id  area_id  zone_id      area_name_en  land_number  \
# 0   1300000003    351.0      2.0  Al Thanyah Third         31.0
# 1   1300000004    351.0      2.0  Al Thanyah Third         34.0
# 2   1300000005    351.0      2.0  Al Thanyah Third         34.0
# 3   1300000006    351.0      2.0  Al Thanyah Third         34.0
# 4   1300000007    351.0      2.0  Al Thanyah Third         34.0
#
#    land_sub_number building_number unit_number  unit_balcony_area  \
# 0              0.0               2         207              19.97
# 1              0.0               1         G01              13.22
# 2              0.0               1         G02              96.20
# 3              0.0               1         G03             106.46
# 4              0.0               1         G04              29.10
#
#   unit_parking_number  ...  pre_registration_number master_project_id  \
# 0         B-63 , B-64  ...                      NaN              33.0
# ...

# %%
units.drop(columns="land_type_ar", inplace = True)
units.head()
# Out:
#    property_id  area_id  zone_id      area_name_en  land_number  \
# 0   1300000003    351.0      2.0  Al Thanyah Third         31.0
# 1   1300000004    351.0      2.0  Al Thanyah Third         34.0
# 2   1300000005    351.0      2.0  Al Thanyah Third         34.0
# 3   1300000006    351.0      2.0  Al Thanyah Third         34.0
# 4   1300000007    351.0      2.0  Al Thanyah Third         34.0
#
#    land_sub_number building_number unit_number  unit_balcony_area  \
# 0              0.0               2         207              19.97
# 1              0.0               1         G01              13.22
# 2              0.0               1         G02              96.20
# 3              0.0               1         G03             106.46
# 4              0.0               1         G04              29.10
#
#   unit_parking_number  ...  is_registered pre_registration_number  \
# 0         B-63 , B-64  ...            1.0                     NaN
# ...

# %%
units.drop(columns="master_project_ar", inplace = True)
units.head()
# Out:
#    property_id  area_id  zone_id      area_name_en  land_number  \
# 0   1300000003    351.0      2.0  Al Thanyah Third         31.0
# 1   1300000004    351.0      2.0  Al Thanyah Third         34.0
# 2   1300000005    351.0      2.0  Al Thanyah Third         34.0
# 3   1300000006    351.0      2.0  Al Thanyah Third         34.0
# 4   1300000007    351.0      2.0  Al Thanyah Third         34.0
#
#    land_sub_number building_number unit_number  unit_balcony_area  \
# 0              0.0               2         207              19.97
# 1              0.0               1         G01              13.22
# 2              0.0               1         G02              96.20
# 3              0.0               1         G03             106.46
# 4              0.0               1         G04              29.10
#
#   unit_parking_number  ...  is_lease_hold is_registered  \
# 0         B-63 , B-64  ...            0.0           1.0
# 1                B-27  ...            0.0           1.0
# ...

# %%
units.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1656716 entries, 0 to 1656715
# Data columns (total 43 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   property_id                 1656716 non-null  int64
#  1   area_id                     1513594 non-null  float64
#  2   zone_id                     1513594 non-null  float64
#  3   area_name_en                1513594 non-null  object
#  4   land_number                 1513594 non-null  float64
#  5   land_sub_number             1455693 non-null  float64
#  6   building_number             1360378 non-null  object
#  7   unit_number                 1513594 non-null  object
#  8   unit_balcony_area           586492 non-null   float64
#  9   unit_parking_number         387006 non-null   object
#  10  parking_allocation_type     8399 non-null     float64
#  11  parking_allocation_type_ar  6598 non-null     object
# ...

# %%
units.isnull().sum()
# Out:
# property_id                         0
# area_id                        143122
# zone_id                        143122
# area_name_en                   143122
# land_number                    143122
# land_sub_number                201023
# building_number                296338
# unit_number                    143122
# unit_balcony_area             1070224
# unit_parking_number           1269710
# parking_allocation_type       1648317
# parking_allocation_type_ar    1650118
# parking_allocation_type_en    1650118
# common_area                    496860
# actual_common_area            1290773
# floor                          435887
# rooms                          629859
# rooms_ar                       629859
# rooms_en                       636729
# actual_area                    190938
# property_type_id               143122
# property_type_ar               143122
# property_type_en               143122
# property_sub_type_id           836755
# property_sub_type_ar           836755
# ...

# %%
units.drop(columns="project_id", inplace = True)
units.head()
# Out:
#    property_id  area_id  zone_id      area_name_en  land_number  \
# 0   1300000003    351.0      2.0  Al Thanyah Third         31.0
# 1   1300000004    351.0      2.0  Al Thanyah Third         34.0
# 2   1300000005    351.0      2.0  Al Thanyah Third         34.0
# 3   1300000006    351.0      2.0  Al Thanyah Third         34.0
# 4   1300000007    351.0      2.0  Al Thanyah Third         34.0
#
#    land_sub_number building_number unit_number  unit_balcony_area  \
# 0              0.0               2         207              19.97
# 1              0.0               1         G01              13.22
# 2              0.0               1         G02              96.20
# 3              0.0               1         G03             106.46
# 4              0.0               1         G04              29.10
#
#   unit_parking_number  ...  is_free_hold is_lease_hold is_registered  \
# 0         B-63 , B-64  ...             1           0.0           1.0
# ...

# %%
units.drop(columns="project_name_ar", inplace = True)
units.head()
# Out:
#    property_id  area_id  zone_id      area_name_en  land_number  \
# 0   1300000003    351.0      2.0  Al Thanyah Third         31.0
# 1   1300000004    351.0      2.0  Al Thanyah Third         34.0
# 2   1300000005    351.0      2.0  Al Thanyah Third         34.0
# 3   1300000006    351.0      2.0  Al Thanyah Third         34.0
# 4   1300000007    351.0      2.0  Al Thanyah Third         34.0
#
#    land_sub_number building_number unit_number  unit_balcony_area  \
# 0              0.0               2         207              19.97
# 1              0.0               1         G01              13.22
# 2              0.0               1         G02              96.20
# 3              0.0               1         G03             106.46
# 4              0.0               1         G04              29.10
#
#   unit_parking_number  ...  parcel_id is_free_hold is_lease_hold  \
# 0         B-63 , B-64  ...  3881500.0            1           0.0
# ...

# %%
units.drop(columns="project_name_en", inplace = True)
units.head()
# Out:
#    property_id  area_id  zone_id      area_name_en  land_number  \
# 0   1300000003    351.0      2.0  Al Thanyah Third         31.0
# 1   1300000004    351.0      2.0  Al Thanyah Third         34.0
# 2   1300000005    351.0      2.0  Al Thanyah Third         34.0
# 3   1300000006    351.0      2.0  Al Thanyah Third         34.0
# 4   1300000007    351.0      2.0  Al Thanyah Third         34.0
#
#    land_sub_number building_number unit_number  unit_balcony_area  \
# 0              0.0               2         207              19.97
# 1              0.0               1         G01              13.22
# 2              0.0               1         G02              96.20
# 3              0.0               1         G03             106.46
# 4              0.0               1         G04              29.10
#
#   unit_parking_number  ...  munc_number  parcel_id is_free_hold  \
# 0         B-63 , B-64  ...       1500.0  3881500.0            1
# ...

# %%
units.drop(columns="pre_registration_number", inplace = True)
units.head()

# %%
units.describe()

# %%
units.mean
