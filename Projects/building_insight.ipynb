# %%
import numpy as np
import pandas as pd
import os

# %%
building=pd.read_csv('Buildings.csv')
# Out:
# C:\Users\phera\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (7,35,37,38,40,41) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
type(building)
# Out:
# pandas.core.frame.DataFrame

# %%
#land=building[['property_id','area_id']]

# %%
#land.head()

# %%
building.head()
# Out:
#    property_id  area_id  zone_id    area_name_ar        area_name_en  \
# 0   1200000001      352        2  الثنيه الرابعة  Al Thanayah Fourth
# 1   1200000003      352        2  الثنيه الرابعة  Al Thanayah Fourth
# 2   1200000005      400        1          العياص             Al Eyas
# 3   1200000006      350        2  الثنيه الخامسة    Al Thanyah Fifth
# 4   1200000008      350        2  الثنيه الخامسة    Al Thanyah Fifth
#
#    land_number  land_sub_number building_number  common_area  \
# 0          220              0.0               3          NaN
# 1          339              0.0              91          NaN
# 2           -1              0.0               1          NaN
# 3           76              0.0        JI05M002          NaN
# 4           81              0.0        JI05M007          NaN
#
#    actual_common_area  ...  pre_registration_number  master_project_id  \
# 0                 NaN  ...                      NaN               50.0
# ...

# %%
building.area_name_en.value_counts().nlargest(10).reset_index()
# Out:
#                                index  area_name_en
# 0                             Mirdif         10403
# 1                 Al Thanayah Fourth          7192
# 2                     Wadi Al Safa 5          5856
# 3                     Wadi Al Safa 7          5258
# 4                   Al Thanyah Fifth          4559
# 5                     Wadi Al Safa 6          4341
# 6  Hadaeq Sheikh Mohammed Bin Rashid          3855
# 7                      Al Yelayiss 1          3672
# 8                    Jabal Ali First          3451
# 9                     Wadi Al Safa 3          3290

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(25,6))

x=building.area_name_en.value_counts().nlargest(10).reset_index()
plt.bar(x['index'],x['area_name_en'])
# Out:
# <BarContainer object of 10 artists>

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(25,6))

#x=building.area_name_en.value_counts().nlargest(10).reset_index()
plt.bar(x['index'],x['project_name_en'])

# %%
import matplotlib.pyplot as plt
#Check how Expense is varying with Age with scatter plot
x = building["rooms"]
y=  building["project_name_en"]
plt.bar(x, y)
plt.title('Age Income chart')
plt.xlabel('age')
plt.ylabel('expense')
plt.show()

# %%
building.shape
# Out:
# (148000, 45)

# %%
building['land_type_en'].unique()
# Out:
# array(['Commercial', 'Residential', nan, 'Industrial',
#        'Government Authorities', 'Public Facilities', 'Agricultural'],
#       dtype=object)

# %%
building['property_sub_type_en'].unique()
# Out:
# array(['Villa', 'Building', 'Factory', 'Nursery', 'Education', 'Clinic ',
#        'Warehouse', 'Hospital '], dtype=object)

# %%
building['is_free_hold'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
building.project_name_en.value_counts().nlargest(10)
# Out:
# JUMEIRAH PARK                                 1794
# THE FIELDS AT D11 - MBRMC                     1028
# VICTORY HEIGHTS                                961
# Elan                                           916
# AL FURJAN                                      835
# JUMEIRAH ISLANDS MANSIONS                      767
# NOOR TOWNHOUSES                                764
# TOWN SQUARE HAYAT                              730
# Vardon @ Akoya Oxygen                          683
# MUDON PHASE 3 _  NEIGHBOURHOOD I- ARABELLA     668
# Name: project_name_en, dtype: int64

# %%
building.master_project_en.value_counts().nlargest(20)
# Out:
# Dubai Tiger Woods              3192
# Jumeirah Village Circle        2923
# Jumeirah Park                  2805
# 558 Villa                      2584
# Dubai World Central            2556
# Mudon                          2480
# Dubai Investment Park First    2366
# Silicon Oasis                  2146
# Akoy                           1965
# Al Furjan                      1795
# Jumeirah Village Triangle      1671
# Jumeirah Islands               1615
# Palm Jumeirah                  1603
# 800 Villas                     1531
# International City Ph 1        1502
# Springs - 1                    1379
# The Villa                      1377
# Jumeirah Golf                  1314
# Dubai Sports City              1260
# Springs - 2                     948
# Name: master_project_en, dtype: int64

# %%
building.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148000 entries, 0 to 147999
# Data columns (total 45 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   property_id              148000 non-null  int64
#  1   area_id                  148000 non-null  int64
#  2   zone_id                  148000 non-null  int64
#  3   area_name_ar             148000 non-null  object
#  4   area_name_en             148000 non-null  object
#  5   land_number              148000 non-null  int64
#  6   land_sub_number          143352 non-null  float64
#  7   building_number          117268 non-null  object
#  8   common_area              69335 non-null   float64
#  9   actual_common_area       31574 non-null   float64
#  10  floors                   112742 non-null  float64
#  11  rooms                    111728 non-null  float64
#  12  rooms_ar                 111677 non-null  object
# ...

# %%
building.describe(include='all')
# Out:
#          property_id        area_id        zone_id area_name_ar area_name_en  \
# count   1.480000e+05  148000.000000  148000.000000       148000       148000
# unique           NaN            NaN            NaN          210          210
# top              NaN            NaN            NaN         مردف       Mirdif
# freq             NaN            NaN            NaN        10403        10403
# mean    1.425861e+09     381.686736       1.779007          NaN          NaN
# std     2.695206e+08      88.646313       0.414917          NaN          NaN
# min     1.200000e+09     229.000000       1.000000          NaN          NaN
# 25%     1.200037e+09     315.000000       2.000000          NaN          NaN
# 50%     1.200076e+09     372.000000       2.000000          NaN          NaN
# 75%     1.800009e+09     463.000000       2.000000          NaN          NaN
# max     1.800090e+09     531.000000       2.000000          NaN          NaN
#
# ...

# %%
building.columns
# Out:
# Index(['property_id', 'area_id', 'zone_id', 'area_name_ar', 'area_name_en',
#        'land_number', 'land_sub_number', 'building_number', 'common_area',
#        'actual_common_area', 'floors', 'rooms', 'rooms_ar', 'rooms_en',
#        'car_parks', 'built_up_area', 'bld_levels', 'shops', 'flats', 'offices',
#        'swimming_pools', 'elevators', 'actual_area', 'property_type_id',
#        'property_type_ar', 'property_type_en', 'property_sub_type_id',
#        'property_sub_type_ar', 'property_sub_type_en', 'parent_property_id',
#        'creation_date', 'parcel_id', 'is_free_hold', 'is_lease_hold',
#        'is_registered', 'pre_registration_number', 'master_project_id',
#        'master_project_en', 'master_project_ar', 'project_id',
#        'project_name_ar', 'project_name_en', 'land_type_id', 'land_type_ar',
#        'land_type_en'],
#       dtype='object')

# %%
building=building.drop(['property_id','area_name_ar','building_number','rooms_ar','rooms_en',
               'property_type_ar', 'property_sub_type_ar','master_project_ar','project_name_ar',
              'land_type_ar'], axis=1)

# %%
building.isnull().sum()
# Out:
# area_id                         0
# zone_id                         0
# area_name_en                    0
# land_number                     0
# land_sub_number              4648
# common_area                 78665
# actual_common_area         116426
# floors                      35258
# rooms                       36272
# car_parks                   24828
# built_up_area               25021
# bld_levels                 143637
# shops                      140682
# flats                      140946
# offices                    140677
# swimming_pools             146745
# elevators                  146698
# actual_area                 13354
# property_type_id                0
# property_type_en                0
# property_sub_type_id            0
# property_sub_type_en            0
# parent_property_id              0
# creation_date               10860
# parcel_id                   20895
# is_free_hold                    0
# is_lease_hold               72814
# ...

# %%
building.head()
# Out:
#    area_id  zone_id        area_name_en  land_number  land_sub_number  \
# 0      352        2  Al Thanayah Fourth          220              0.0
# 1      352        2  Al Thanayah Fourth          339              0.0
# 2      400        1             Al Eyas           -1              0.0
# 3      350        2    Al Thanyah Fifth           76              0.0
# 4      350        2    Al Thanyah Fifth           81              0.0
#
#    common_area  actual_common_area  floors  rooms  car_parks  ...  \
# 0          NaN                 NaN     NaN    NaN        NaN  ...
# 1          NaN                 NaN     NaN    NaN        NaN  ...
# 2          NaN                 NaN     NaN    1.0        NaN  ...
# 3          NaN                 NaN     2.0    4.0        2.0  ...
# 4          NaN                 NaN     2.0    4.0        2.0  ...
#
#    is_free_hold  is_lease_hold  is_registered  pre_registration_number  \
# 0             1            0.0            1.0                      NaN
# ...

# %%
df1=building.dropna(axis=1,how='any',inplace=False)
#df= building['shops'].dropna(axis=0)

# %%
df1.head()
# Out:
#    area_id  zone_id        area_name_en  land_number  property_type_id  \
# 0      352        2  Al Thanayah Fourth          220                 2
# 1      352        2  Al Thanayah Fourth          339                 2
# 2      400        1             Al Eyas           -1                 2
# 3      350        2    Al Thanyah Fifth           76                 2
# 4      350        2    Al Thanyah Fifth           81                 2
#
#   property_type_en  property_sub_type_id property_sub_type_en  \
# 0         Building                     4                Villa
# 1         Building                     4                Villa
# 2         Building                     4                Villa
# 3         Building                     4                Villa
# 4         Building                     4                Villa
#
#    parent_property_id  is_free_hold
# 0               65195             1
# 1               65227             1
# 2                  -1             0
# ...

# %%
df1.isnull().sum()
# Out:
# area_id                 0
# zone_id                 0
# area_name_en            0
# land_number             0
# property_type_id        0
# property_type_en        0
# property_sub_type_id    0
# property_sub_type_en    0
# parent_property_id      0
# is_free_hold            0
# dtype: int64

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.shape
# Out:
# (148000, 10)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148000 entries, 0 to 147999
# Data columns (total 10 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   area_id               148000 non-null  int64
#  1   zone_id               148000 non-null  int64
#  2   area_name_en          148000 non-null  object
#  3   land_number           148000 non-null  int64
#  4   property_type_id      148000 non-null  int64
#  5   property_type_en      148000 non-null  object
#  6   property_sub_type_id  148000 non-null  int64
#  7   property_sub_type_en  148000 non-null  object
#  8   parent_property_id    148000 non-null  int64
#  9   is_free_hold          148000 non-null  int64
# dtypes: int64(7), object(3)
# memory usage: 11.3+ MB

# %%
building.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148000 entries, 0 to 147999
# Data columns (total 35 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   area_id                  148000 non-null  int64
#  1   zone_id                  148000 non-null  int64
#  2   area_name_en             148000 non-null  object
#  3   land_number              148000 non-null  int64
#  4   land_sub_number          143352 non-null  float64
#  5   common_area              69335 non-null   float64
#  6   actual_common_area       31574 non-null   float64
#  7   floors                   112742 non-null  float64
#  8   rooms                    111728 non-null  float64
#  9   car_parks                123172 non-null  float64
#  10  built_up_area            122979 non-null  float64
#  11  bld_levels               4363 non-null    float64
#  12  shops                    7318 non-null    float64
# ...

# %%
building.built_up_area.head(10)
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3    490.99
# 4    490.99
# 5    473.90
# 6    480.87
# 7    473.90
# 8    480.96
# 9    477.89
# Name: built_up_area, dtype: float64

# %%
building.columns
# Out:
# Index(['area_id', 'zone_id', 'area_name_en', 'land_number', 'land_sub_number',
#        'common_area', 'actual_common_area', 'floors', 'rooms', 'car_parks',
#        'built_up_area', 'bld_levels', 'shops', 'flats', 'offices',
#        'swimming_pools', 'elevators', 'actual_area', 'property_type_id',
#        'property_type_en', 'property_sub_type_id', 'property_sub_type_en',
#        'parent_property_id', 'creation_date', 'parcel_id', 'is_free_hold',
#        'is_lease_hold', 'is_registered', 'pre_registration_number',
#        'master_project_id', 'master_project_en', 'project_id',
#        'project_name_en', 'land_type_id', 'land_type_en'],
#       dtype='object')

# %%
shop_df=building['shops']

# %%
shop_df1=shop_df.dropna()

# %%
shop_df1
# Out:
# 7704     6.0
# 7705     4.0
# 7706     4.0
# 7707     3.0
# 7708     3.0
#         ...
# 82138    2.0
# 82269    5.0
# 82270    0.0
# 82287    0.0
# 82536    0.0
# Name: shops, Length: 7318, dtype: float64

# %%
building
# Out:
#         area_id  zone_id        area_name_en  land_number  land_sub_number  \
# 0           352        2  Al Thanayah Fourth          220              0.0
# 1           352        2  Al Thanayah Fourth          339              0.0
# 2           400        1             Al Eyas           -1              0.0
# 3           350        2    Al Thanyah Fifth           76              0.0
# 4           350        2    Al Thanyah Fifth           81              0.0
# ...         ...      ...                 ...          ...              ...
# 147995      299        1     Al Warqa Fourth           54              0.0
# 147996      328        2          Al Jafliya          439              0.0
# 147997      233        1          Hor Al Anz         1171              0.0
# 147998      232        1              Mirdif            3           1472.0
# 147999      264        1        Nad Al Hamar         1533              0.0
#
# ...
